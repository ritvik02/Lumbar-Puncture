# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#Function for image preprocessing
def preprocess_ultrasonic_scan(image_path):
    # Load the image
    image = cv2.imread(image_path)

    # Convert the image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur to reduce noise
    blurred_image = cv2.GaussianBlur(gray_image, (7, 7), 0)

    # Apply contrast enhancement using histogram equalization
    equalized_image = cv2.equalizeHist(blurred_image)

    # Resize the image to a desired size (e.g., 800x600)
    desired_size = (800, 600)
    resized_image = cv2.resize(equalized_image, desired_size)

    return resized_image

# %%
input_image_path = "152.jpg"
preprocessed_image = preprocess_ultrasonic_scan(input_image_path)

# Load the original image
original_image = cv2.imread(input_image_path)

# Display both the input (original) and preprocessed images side by side
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(preprocessed_image, cmap='gray')
plt.title("Preprocessed Image")
plt.axis('off')

plt.show()

# %%
#Using different histogram equalization technique
def preprocess_ultrasonic_scan_with_contrast_enhancement(image_path):
    # Load the image
    image = cv2.imread(image_path)

    # Convert the image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply adaptive histogram equalization for contrast enhancement
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced_image = clahe.apply(gray_image)

    # Resize the image to a desired size (e.g., 800x600)
    desired_size = (800, 600)
    resized_image = cv2.resize(enhanced_image, desired_size)

    return resized_image

# %%
input_image_path = "152.jpg"
preprocessed_image = preprocess_ultrasonic_scan_with_contrast_enhancement(input_image_path)

# Save the preprocessed image
output_image_path = "preprocessed_ultrasound_image_with_contrast_enhancement.jpg"
cv2.imwrite(output_image_path, preprocessed_image)

# Load the original image
original_image = cv2.imread(input_image_path)

# Display both the input (original) and preprocessed images side by side
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(preprocessed_image, cmap='gray')
plt.title("Preprocessed Image")
plt.axis('off')

plt.show()
